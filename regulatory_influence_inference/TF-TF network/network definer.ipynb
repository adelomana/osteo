# %% [markdown]
# This script reads regulons and builds the input file for Cytoscape.

# %%
# consider building black nodes with size of target genes
# consider building size of TF as target genes.
# nodes will be blue or red depending or upregulated or downregulated genes.

# %%
import pandas

# %% [markdown]
# # 0. user-defined variables

# %%
#! drangajokull
home_dir = '/home/adrian/'

#! necio5
home_dir = '/Users/adrian/'

# %%
regulons_up_file = home_dir + 'gd15/hi/research/osteo/results/regulons/regulons_up.csv'
regulons_down_file = home_dir + 'gd15/hi/research/osteo/results/regulons/regulons_down.csv'

interactions_output_file = home_dir + 'gd15/hi/research/osteo/results/TF-TF_network/interactions.csv'
regulon_descriptions_output_file = home_dir + 'gd15/hi/research/osteo/results/TF-TF_network/descriptions.csv'

# %% [markdown]
# # 1. read regulons

# %%
up = pandas.read_csv(regulons_up_file, index_col=0, sep='\t')
print(up.shape)
up.head()
# Out:
# (51, 10)
#                 TF  Regulon size  \
# Regulon ID
# PRRX2.31     PRRX2            31
# JDP2.13       JDP2            13
# RORB.2        RORB             2
# NFATC4.6    NFATC4             6
# POU6F1.3    POU6F1             3
#
#                                                  Target genes  TF-targets PCC  \
# Regulon ID
# PRRX2.31    CH25H, PTGES, PTGER2, FAM20C, CYGB, STOM, NEBL...           0.842
# JDP2.13     CCND2, TMEM100, EPHX1, CYGB, MMP28, DCN, DDR2,...           0.936
# RORB.2                                            PID1, BTBD3           0.941
# NFATC4.6     PODN, ADAMTS10, C11orf95, MAP3K12, FAM20A, VWA5A           0.902
# POU6F1.3                          ADAMTS10, C11orf95, MAP3K12           0.829
#
#             Enrichment corrected P value  Activity on Day 3  \
# Regulon ID
# PRRX2.31                          0.0428             -1.648
# JDP2.13                           0.0450             -1.423
# RORB.2                            0.0701             -1.204
# NFATC4.6                          0.0610             -1.375
# POU6F1.3                          0.0530             -1.272
#
#             Activity on Day 6  Activity on Day 9  Activity on Day 16  \
# Regulon ID
# PRRX2.31               -0.292              0.815               0.325
# JDP2.13                -0.586              0.409               0.274
# RORB.2                 -0.934             -0.068               0.802
# NFATC4.6                0.791              1.258              -0.088
# POU6F1.3                0.603              1.527              -0.378
#
#             Activity on Day 28
# Regulon ID
# PRRX2.31                 0.799
# JDP2.13                  1.327
# RORB.2                   1.404
# NFATC4.6                -0.585
# POU6F1.3                -0.481

# %%
down = pandas.read_csv(regulons_down_file, index_col=0, sep='\t')
print(down.shape)
down.head()
# Out:
# (60, 10)
#                TF  Regulon size  \
# Regulon ID
# CXXC1.7     CXXC1             7
# E2F1.30      E2F1            30
# E2F4.49      E2F4            49
# E2F7.2       E2F7             2
# E2F8.123     E2F8           123
#
#                                                  Target genes  TF-targets PCC  \
# Regulon ID
# CXXC1.7     BCL2L12, CHTF18, RECQL4, ATAD3B, POLE, PASK, H...           0.891
# E2F1.30     DTL, CDCA7, UHRF1, FANCA, POLA2, CDT1, MYBL2, ...           0.942
# E2F4.49     CDCA7, FEN1, ORC1, POLA2, CDT1, MCM3, MYBL2, C...           0.838
# E2F7.2                                            E2F1, UHRF1           0.966
# E2F8.123    UHRF1, FEN1, PASK, DTL, VRK1, INCENP, TCF19, E...           0.889
#
#             Enrichment corrected P value  Activity on Day 3  \
# Regulon ID
# CXXC1.7                           0.0484              1.722
# E2F1.30                           0.0215              1.714
# E2F4.49                           0.0000              1.670
# E2F7.2                            0.0241              1.803
# E2F8.123                          0.0108              1.704
#
#             Activity on Day 6  Activity on Day 9  Activity on Day 16  \
# Regulon ID
# CXXC1.7                -0.243             -0.231               0.083
# E2F1.30                 0.043             -0.640               0.083
# E2F4.49                 0.055             -0.708               0.186
# E2F7.2                  0.011             -0.291              -0.291
# E2F8.123                0.044             -0.641               0.091
#
#             Activity on Day 28
# Regulon ID
# CXXC1.7                 -1.331
# E2F1.30                 -1.199
# E2F4.49                 -1.202
# E2F7.2                  -1.231
# E2F8.123                -1.198

# %% [markdown]
# # 2. establish interactions

# %%
# get full list of TFs
TFs_up = up['TF'].to_list() 
print(len(TFs_up))
TFs_down = down['TF'].to_list()
print(len(TFs_down))

all_TFs = list(set(TFs_up + TFs_down))
print(len(all_TFs))
# Out:
# 51
# 60
# 111

# %%
interactions = []
for TF in all_TFs:
    print(TF)
    
    # up
    container_list = up[up['TF'] == TF]['Target genes'].to_list()
    if len(container_list) > 0:
        targets = container_list[0].split(', ')
        print('\t up {}'.format(targets))
        for target in targets:
            if target in all_TFs:
                print('\t {}'.format(target))
                interactions.append((TF, target))
    
    # down        
    container_list = down[down['TF'] == TF]['Target genes'].to_list()
    if len(container_list) > 0:
        targets = container_list[0].split(', ')
        print('\t down {}'.format(targets))
        for target in targets:
            if target in all_TFs:
                print('\t {}'.format(target))
                interactions.append((TF, target))
                
print(interactions, len(interactions))
# Out:
# ZNF215
# 	 down ['TYMS', 'EXO1', 'ZWILCH', 'TTK', 'GINS4', 'CDC6', 'RFC3', 'GINS2', 'STIL']
# YBX3
# 	 up ['MEDAG', 'CEBPB', 'RAB31', 'BTG1', 'NDRG1', 'GJA1', 'STOM', 'SERPINA3', 'GYPC', 'IL1R2', 'IL1R1', 'ACKR1', 'SPRY1', 'CDKN1A', 'CRISPLD2', 'SLC7A2', 'C1QTNF1']
# 	 CEBPB
# KLF15
# 	 up ['ZBTB16', 'BCL6', 'STON1', 'GABARAPL1', 'GALNT15', 'CEBPD', 'USP53', 'CALCOCO2', 'RGCC', 'INSR', 'CDKN1C', 'ADHFE1']
# HDX
# 	 down ['MMP16', 'CNTNAP1']
# E4F1
# 	 down ['KIF22', 'NOP2', 'MYBBP1A', 'THOP1', 'NCLN']
# OSR2
# 	 up ['MEDAG', 'PPARG', 'THBS2', 'NUDT4', 'FBLN2', 'DPT', 'FZD4', 'TSC22D3', 'SFRP1', 'ISM1', 'CRLF1', 'LAMA2', 'CORO6', 'CFD', 'PMP22', 'C7', 'MFAP4', 'NBL1']
# 	 PPARG
# ZNF668
# 	 down ['SLC27A4', 'NCLN', 'TUBG1']
# NPAS1
# 	 down ['PAFAH1B3', 'LPCAT4']
# SOX12
# 	 down ['MAP4K2', 'LPCAT4']
# PPARG
# 	 up ['NR1D1', 'SAT1']
# MYBL2
# 	 down ['TOP2A', 'CENPF']
# GLIS3
# 	 up ['CFH', 'LAYN', 'CBX7', 'C1S', 'EFEMP1']
# ZFP90
# 	 up ['C11orf95', 'MAP3K12']
# HIF3A
# 	 up ['ABCA6', 'EPHB6', 'ABCA9']
# HIVEP3
# 	 down ['NECTIN1', 'UHRF1', 'WDR4', 'EPHB2', 'SHB']
# RORA
# 	 up ['ANGPT1', 'PLEKHH2', 'BCL6', 'CREBRF', 'C1orf21', 'GABARAPL1', 'ANKRD28', 'USP53']
# TSC22D1
# 	 up ['PDK4', 'BTG2', 'WASL', 'ANTXR2', 'OSGIN2', 'NUDT4', 'PKIG', 'BTG1', 'KLF9', 'TSC22D3', 'SSBP2', 'ENPP4', 'SESN1', 'NEDD9', 'EPS8', 'CDKN1C']
# ZNF521
# 	 up ['CFI', 'LAMA4', 'KCNT2', 'ADAMTS5', 'RFTN2', 'PLXDC2', 'ANGPTL2', 'PCDH18', 'LEPR', 'EPHX1', 'CYGB', 'DCN', 'CADM3', 'GAS1', 'DDR2', 'PROS1', 'LCA5', 'SLC40A1', 'SESN3', 'OLFML2A', 'DNAJC6', 'SVEP1', 'SERPING1', 'IFITM1', 'SLC9A9', 'ASAP3', 'HTRA1', 'GPC6', 'RNF144A', 'FBLN1', 'CYBRD1', 'CFH', 'HNMT', 'EBF1', 'ECM2', 'LUM', 'GPNMB', 'VCAM1', 'RTN4RL2', 'PMP22', 'MFAP4', 'TMEM150C', 'SSPN', 'SLIT3', 'COL21A1']
# 	 EBF1
# HLX
# 	 up ['RARRES2', 'FAM110B']
# FOXL1
# 	 down ['PEAR1', 'PLEKHG5']
# SP100
# 	 up ['PLEKHH2', 'CREBRF', 'STON1', 'YPEL2', 'ANKRD28', 'CCNG2', 'TP53INP1', 'BST2', 'PLSCR1', 'FGF7', 'RCN1', 'PNRC1', 'CREG1']
# ZNF749
# 	 down ['MYBBP1A', 'PFAS', 'NOP2', 'NOP56']
# NFE2L3
# 	 down ['EZH2', 'MTFR2', 'HAUS8', 'PASK', 'LIG1', 'ORC6', 'PLK1', 'HELLS', 'FANCI']
# E2F8
# 	 down ['UHRF1', 'FEN1', 'PASK', 'DTL', 'VRK1', 'INCENP', 'TCF19', 'E2F1', 'NECTIN1', 'FANCA', 'ORC1', 'DEPDC1B', 'CDC25A', 'CENPO', 'EZH2', 'MTFR2', 'CDCA7', 'CLSPN', 'ESCO2', 'SKA1', 'MYBL2', 'CDT1', 'WDR62', 'PLEK2', 'XRCC2', 'CENPI', 'WDR76', 'FAM111B', 'FIGNL1', 'MCM10', 'SPC24', 'CENPW', 'NEK2', 'ZWILCH', 'MCM2', 'CDCA2', 'CENPE', 'NCAPG', 'GTSE1', 'BUB1B', 'CEP55', 'GINS1', 'CKS2', 'CDCA8', 'TTK', 'CENPA', 'PAQR4', 'CDC6', 'RACGAP1', 'GINS2', 'RAD54L', 'TYMS', 'EXO1', 'BUB1', 'KIF14', 'FAM83D', 'GINS4', 'POC1A', 'STIL', 'CHAF1B', 'OIP5', 'PLK4', 'SHCBP1', 'KIF23', 'ESPL1', 'AURKA', 'KIF18B', 'BRCA1', 'KIF4A', 'HMMR', 'CENPU', 'IQGAP3', 'CDC45', 'SKA3', 'KIFC1', 'NUF2', 'RAD51', 'NCAPH', 'DBF4', 'NDC80', 'ZWINT', 'TPX2', 'TROAP', 'ANLN', 'TRIP13', 'CENPM', 'MAD2L1', 'MKI67', 'CDK1', 'FANCI', 'CDCA3', 'ORC6', 'KIF18A', 'TACC3', 'PRR11', 'CIT', 'PKMYT1', 'HJURP', 'FOXM1', 'ARHGAP11A', 'MELK', 'CCNF', 'CDC20', 'CDCA5', 'CENPK', 'UBE2T', 'KIF20B', 'PRC1', 'CKAP2L', 'EME1', 'RAD51AP1', 'PLK1', 'ASF1B', 'HELLS', 'SGO2', 'PARPBP', 'CHAF1A', 'BIRC5', 'KIF11', 'LMNB1', 'MCM5', 'AURKB', 'MND1']
# 	 E2F1
# 	 MYBL2
# 	 FOXM1
# ZNF581
# 	 up ['NATD1', 'DHRS3']
# CREBL2
# 	 up ['PIK3IP1', 'PCMTD1']
# MXD3
# 	 down ['CDCA3', 'LIG1', 'ORC6', 'TACC3', 'EME1', 'PLK1', 'TROAP']
# ZNF485
# 	 down ['PFAS', 'NOP2', 'NOP56', 'WRAP53', 'SLC25A19', 'CAD', 'QSOX2']
# ZNF530
# 	 down ['KIF22', 'FUS', 'SUV39H1', 'MCM2', 'RFC3', 'DSN1', 'SPDL1', 'CHAF1B']
# ZNF300
# 	 down ['TYMS', 'ZWILCH', 'RFC3', 'SPDL1', 'CHAF1B']
# KLF16
# 	 down ['FJX1', 'TNFRSF10D', 'CCDC86', 'FOSL1', 'NOP56', 'TUBB4B', 'NOP2', 'PNP', 'NCLN']
# WIZ
# 	 down ['NOP56', 'NOP2', 'IFRD2', 'RRS1', 'THOP1', 'PFAS', 'TUBG1', 'MYBBP1A', 'SLC27A4', 'NCLN']
# E2F7
# 	 down ['E2F1', 'UHRF1']
# 	 E2F1
# ZNF296
# 	 down ['EZH2', 'CHTF18', 'RECQL4', 'PSD4', 'PASK', 'MYBL2', 'CDT1', 'SLC25A10']
# 	 MYBL2
# RORB
# 	 up ['PID1', 'BTBD3']
# BATF3
# 	 down ['ANGPTL4', 'NOP56', 'NOP2', 'SLC2A6', 'PNP']
# ZNF107
# 	 down ['MCM5', 'KIF11', 'ARHGAP11A', 'HELLS']
# NFATC3
# 	 down ['SLC25A19', 'CAD', 'WRAP53', 'MTFP1', 'SMTN', 'PPRC1']
# E2F3
# 	 down ['MCM5', 'AURKA', 'PLK1']
# FOS
# 	 up ['MMP7', 'DDIT3']
# PIN1
# 	 down ['BUB1', 'CENPA']
# FOXC1
# 	 up ['FIBIN', 'LAMA4', 'FMOD', 'STOM', 'APOD', 'EPAS1', 'DCN', 'GYPC', 'FRZB', 'FOXO1', 'DDR2', 'PROS1', 'IL1R1', 'ACKR1', 'CDKN1A', 'SRPX', 'GPX3', 'SERPING1', 'MFGE8', 'SERPINF1', 'KLF11', 'C1R', 'NDNF', 'ATP8B4', 'IGF2', 'SCG2', 'GPC6', 'FBLN1', 'HMCN1', 'ARHGAP6', 'CFD', 'C7', 'MFAP4', 'NBL1']
# 	 FOXO1
# 	 KLF11
# DBP
# 	 up ['OSGIN2', 'GBE1', 'IL1RL1', 'PTPRG', 'GLUL']
# E2F4
# 	 down ['CDCA7', 'FEN1', 'ORC1', 'POLA2', 'CDT1', 'MCM3', 'MYBL2', 'CDC25A', 'FBXO5', 'E2F1', 'CENPO', 'SMC2', 'TOP2A', 'UBE2C', 'CDC25C', 'NUSAP1', 'CCNB1', 'CALM1', 'SUV39H1', 'MCM10', 'TYMS', 'MCM8', 'NEK2', 'GINS1', 'TTK', 'CDC6', 'CENPE', 'RFC3', 'CKS2', 'RAD54L', 'TMPO', 'BRCA1', 'HMMR', 'CDC45', 'RAD51', 'DBF4', 'NDC80', 'ANLN', 'MKI67', 'CDK1', 'MAD2L1', 'PRR11', 'FOXM1', 'PRC1', 'PLK1', 'ASF1B', 'BIRC5', 'AURKB', 'MCM5']
# 	 MYBL2
# 	 E2F1
# 	 FOXM1
# EBF3
# 	 down ['SNCG', 'PEAR1']
# ZNF350
# 	 up ['NFYB', 'TCP11L2']
# ZGPAT
# 	 down ['BCL2L12', 'PLCB3', 'ATAD3B', 'POLE', 'CENPO', 'NOP2', 'PFAS', 'SLC2A6', 'MYBBP1A', 'THOP1', 'NCLN', 'FUS', 'WRAP53', 'SLC19A1', 'TONSL', 'QSOX2']
# FOXO3
# 	 up ['CCNG2', 'BCL6']
# ZBED3
# 	 up ['METTL7A', 'CD302', 'CIDEC', 'RASL10B']
# ZNF239
# 	 down ['NOP56', 'NOP2', 'WDR77', 'RRS1', 'CHAC2', 'PFAS', 'SLC27A4', 'MYBBP1A', 'THOP1']
# ZBED4
# 	 down ['NOP56', 'NOP2', 'WDR77', 'CHAC2', 'PFAS', 'SLC27A4', 'THOP1', 'NCLN', 'KPNA2', 'WRAP53', 'SLC25A19', 'CAD', 'QSOX2']
# ZNF74
# 	 down ['MT1X', 'SLC25A19', 'TONSL', 'CAD']
# EBF1
# 	 up ['EEPD1', 'ST3GAL5']
# GATAD2A
# 	 down ['TNFRSF10D', 'CCDC86', 'FOSL1', 'FJX1', 'MT2A', 'TPM3', 'SEC14L2', 'PNP', 'ANGPTL4', 'TUBB4B', 'NOP56', 'NOP2', 'IFRD2', 'RRS1', 'MYBBP1A', 'SLC27A4', 'NCLN', 'KPNA2']
# ARID5A
# 	 up ['CEBPB', 'KDM7A', 'PKIG', 'GEM', 'BTG1', 'EPS8', 'PELI1']
# 	 CEBPB
# ZNF512B
# 	 down ['MYBBP1A', 'KIF22', 'FUS', 'PFAS']
# ZBTB17
# 	 down ['NOP2', 'IFRD2', 'SLC2A6', 'THOP1', 'NCLN']
# ZNF202
# 	 down ['NOP56', 'NOP2', 'RRS1', 'PFAS', 'FUS']
# RLF
# 	 up ['PELI1', 'CFAP69']
# ZBTB38
# 	 up ['ENPP4', 'MYLK', 'MBNL2']
# ARID5B
# 	 up ['GBP2', 'TLR4', 'BCL6', 'STON1', 'GABARAPL1', 'YPEL2', 'TENM2', 'MAP3K5', 'CEBPD', 'USP53', 'LMCD1', 'CFH', 'EBF1', 'ECM2', 'C1S', 'PDGFRA', 'FGF7', 'PNRC1', 'PLSCR1']
# 	 EBF1
# TBX19
# 	 up ['TM4SF20', 'WDR86']
# TEF
# 	 up ['PPL', 'NR1D2', 'CBX7']
# ATF5
# 	 down ['RRS1', 'RPL26', 'NOP56']
# TRERF1
# 	 down ['MMP16', 'MAP4K2', 'PIF1', 'LPCAT4', 'CARD10', 'SH3BP1', 'CNTNAP1']
# E2F1
# 	 down ['DTL', 'CDCA7', 'UHRF1', 'FANCA', 'POLA2', 'CDT1', 'MYBL2', 'CDC25A', 'FBXO5', 'MCM10', 'TYMS', 'MCM8', 'CDC6', 'RACGAP1', 'PRIM2', 'PLK4', 'KIF23', 'BRCA1', 'AURKA', 'RAD51', 'DBF4', 'PLK1', 'ASF1B', 'HELLS', 'FOXM1', 'CDC45', 'BIRC5', 'DNMT1', 'MCM5', 'CDK1']
# 	 MYBL2
# 	 FOXM1
# GTF3A
# 	 down ['RPS10', 'RPL26', 'NOP56', 'NOP2', 'WDR77', 'IFRD2', 'RRS1', 'CHAC2', 'PFAS', 'SLC2A6', 'TUBG1', 'KPNA2', 'FUS']
# BHLHE40
# 	 up ['VGLL4', 'NR1D1']
# GLYR1
# 	 down ['BUB1B', 'EXO1', 'BUB1', 'CDCA2', 'RACGAP1', 'RAD54L', 'STIL', 'PRC1', 'NCAPH', 'HELLS', 'DNMT1', 'ANLN', 'MELK', 'FANCI']
# YBX1
# 	 down ['TOP2A', 'CCNB1', 'CKS2', 'TYMS']
# PRDM15
# 	 down ['MYBBP1A', 'PFAS', 'NOP2', 'FUS']
# ZNF394
# 	 up ['OVGP1', 'OLFML2B']
# CEBPB
# 	 up ['ADM', 'IGF2']
# PLAG1
# 	 up ['PIK3IP1', 'PCMTD1']
# ARNT
# 	 up ['ANGPT1', 'TENM2']
# ZNF335
# 	 down ['RPS10', 'PFAS', 'MYBBP1A', 'NCLN', 'FUS']
# ZBTB47
# 	 up ['GYPC', 'STAT5A', 'ANGPTL1', 'DDR2', 'FMOD', 'SERPING1', 'MFGE8', 'SERPINF1', 'IFITM3', 'C1R', 'HTRA1', 'ZCCHC24', 'JDP2', 'SLIT3', 'C1QTNF1']
# 	 JDP2
# HOXB3
# 	 down ['PEAR1', 'CPT1C', 'PLEKHG5']
# ZNF710
# 	 down ['NECTIN1', 'UHRF1', 'FEN1', 'INCENP', 'PSD4', 'PAFAH1B3', 'SH3BP1', 'ARRB1']
# ATF4
# 	 up ['CEBPB', 'DDIT3', 'DDR2', 'DDIT4', 'NUPR1']
# 	 CEBPB
# TFDP2
# 	 up ['PLEKHH2', 'CREBRF', 'YPEL2', 'ANKRD28', 'C1orf21', 'INSR', 'ADHFE1']
# ZNF682
# 	 down ['SUV39H1', 'ZWILCH', 'TYMS', 'STIL']
# KLF11
# 	 up ['NR1D2', 'OTUD1']
# ZNF41
# 	 down ['DKK2', 'ARHGAP18', 'RBL1', 'PDCD1LG2']
# SNAI2
# 	 up ['CRISPLD2', 'C1QTNF1']
# PRRX2
# 	 up ['CH25H', 'PTGES', 'PTGER2', 'FAM20C', 'CYGB', 'STOM', 'NEBL', 'DCN', 'CADM3', 'PTGFR', 'ACSL1', 'FMOD', 'IL1R1', 'IFITM1', 'SERPINF1', 'IFITM3', 'ADH1B', 'C1R', 'PLAU', 'KCNK15', 'IGF2', 'SAMHD1', 'FBLN1', 'LBP', 'TOX2', 'BOC', 'G0S2', 'RTN4RL2', 'CFD', 'MFAP4', 'NBL1']
# NFATC4
# 	 up ['PODN', 'ADAMTS10', 'C11orf95', 'MAP3K12', 'FAM20A', 'VWA5A']
# NKX3-2
# 	 up ['PCMTD1', 'PTK2B']
# ZNF93
# 	 down ['DTL', 'CLSPN', 'FBXO5', 'ESCO2', 'KNL1', 'ARHGAP11B', 'POLQ', 'KIF15', 'ECT2', 'CDK1', 'HELLS', 'FOXM1', 'CDC45', 'PARPBP', 'ARHGAP11A', 'MAD2L1', 'FANCI', 'CENPK']
# 	 FOXM1
# ZNF629
# 	 down ['MYBBP1A', 'PFAS', 'WDR77', 'RRS1']
# TWIST1
# 	 up ['CDKN1A', 'SRPX']
# CXXC1
# 	 down ['BCL2L12', 'CHTF18', 'RECQL4', 'ATAD3B', 'POLE', 'PASK', 'HAUS8']
# ZNF726
# 	 down ['CHTF18', 'FANCA', 'POLA2', 'SKA1', 'ESCO2', 'PASK', 'KNL1', 'C21orf58', 'ARHGAP11B', 'KIF2C', 'RRM2', 'CCNB2', 'SPAG5', 'POLQ', 'TRAIP', 'SGO1', 'ZWILCH', 'GINS1', 'BUB1', 'KIF14', 'GINS4', 'CENPE', 'DSN1', 'STIL', 'LIG1', 'NUF2', 'ORC6', 'PRC1', 'PRR11', 'RAD51AP1', 'EME1', 'HELLS', 'FOXM1', 'PARPBP', 'CHAF1A', 'TROAP', 'KIF11', 'MCM5', 'CCNF', 'CDC20', 'CENPK']
# 	 FOXM1
# TCF21
# 	 up ['FBLN2', 'PDE1A', 'SFRP1', 'DPT', 'OSR2', 'RARRES2', 'ANTXR1', 'MYLK', 'NCAM2', 'A2M']
# 	 OSR2
# MYBL1
# 	 down ['CENPI', 'DOCK10', 'SGCD', 'PIF1', 'VEPH1']
# ZNF714
# 	 down ['KNL1', 'ARHGAP11B', 'BUB1B', 'GINS4', 'MCM2', 'CENPE', 'RFC3', 'STIL', 'KIF20B', 'PRR11', 'RAD51AP1', 'EME1', 'HELLS', 'KIF11']
# JDP2
# 	 up ['CCND2', 'TMEM100', 'EPHX1', 'CYGB', 'MMP28', 'DCN', 'DDR2', 'TSC22D1', 'TSC22D3', 'FBLN2', 'DPT', 'GPNMB', 'VCAM1']
# 	 TSC22D1
# FOXO1
# 	 up ['DUSP4', 'CNR1']
# MLX
# 	 down ['NOP56', 'WDR77', 'RRS1', 'CHAC2', 'TUBG1', 'SLC27A4']
# TBX15
# 	 up ['SMOC1', 'DCN', 'ANGPTL1', 'FOXO1', 'DDR2', 'FMOD']
# 	 FOXO1
# TGIF1
# 	 up ['MAP3K8', 'INHBB', 'MEDAG', 'PLPP1', 'CEBPB', 'PKIG', 'BTG1', 'ABHD4', 'TLE2', 'GABARAPL1', 'YPEL2', 'ANKRD28', 'MAP3K5', 'CEBPD', 'TLE6', 'ARHGAP6', 'PMP22', 'RAP1B', 'SOD2']
# 	 CEBPB
# ZNF324B
# 	 down ['MYBBP1A', 'PFAS', 'WDR77']
# ZNF22
# 	 up ['NUDT4', 'IL18R1', 'PPARG', 'PCDH18']
# 	 PPARG
# ZNF324
# 	 down ['MYBBP1A', 'PFAS', 'FUS', 'NOP56']
# TFDP1
# 	 down ['CKAP2L', 'CDK1']
# FOXM1
# 	 down ['CDC25C', 'CCNB1', 'CENPF', 'CDC6', 'CENPA', 'AURKB', 'CDK1', 'PLK1', 'BIRC5']
# PRDM16
# 	 down ['ATP10A', 'PCDH10', 'NES', 'SNCG', 'PEAR1']
# ATOH8
# 	 up ['TIMP4', 'SRPX']
# MEOX2
# 	 down ['B4GALNT1', 'LRRC17', 'PCDH19', 'DOCK10', 'SGCD', 'FAM180A', 'PLD5']
# MEF2A
# 	 up ['MYLK', 'NEDD9']
# POU6F1
# 	 up ['ADAMTS10', 'C11orf95', 'MAP3K12']
# [('YBX3', 'CEBPB'), ('OSR2', 'PPARG'), ('ZNF521', 'EBF1'), ('E2F8', 'E2F1'), ('E2F8', 'MYBL2'), ('E2F8', 'FOXM1'), ('E2F7', 'E2F1'), ('ZNF296', 'MYBL2'), ('FOXC1', 'FOXO1'), ('FOXC1', 'KLF11'), ('E2F4', 'MYBL2'), ('E2F4', 'E2F1'), ('E2F4', 'FOXM1'), ('ARID5A', 'CEBPB'), ('ARID5B', 'EBF1'), ('E2F1', 'MYBL2'), ('E2F1', 'FOXM1'), ('ZBTB47', 'JDP2'), ('ATF4', 'CEBPB'), ('ZNF93', 'FOXM1'), ('ZNF726', 'FOXM1'), ('TCF21', 'OSR2'), ('JDP2', 'TSC22D1'), ('TBX15', 'FOXO1'), ('TGIF1', 'CEBPB'), ('ZNF22', 'PPARG')] 26

# %% [markdown]
# # 3. store results

# %%
with open(interactions_output_file, 'w') as f:
    f.write('source\ttarget\n')
    for interaction in interactions:
        f.write('{}\t{}\n'.format(interaction[0], interaction[1]))

# %%
with open(regulon_descriptions_output_file, 'w') as f:
    f.write('node\tregulation\tsize\n')
    
    for element in up.index: 
        node = up.loc[element, 'TF']
        regulation = 'up'
        size = up.loc[element, 'Regulon size']
        f.write('{}\t{}\t{}\n'.format(node, regulation, size))
        
    for element in down.index: 
        node = down.loc[element, 'TF']
        regulation = 'down'
        size = down.loc[element, 'Regulon size']
        f.write('{}\t{}\t{}\n'.format(node, regulation, size))
